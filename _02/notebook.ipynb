# %% [markdown]
# # 03

# %%
# Модуль 2.1: Ввід (`input`) та вивід (`print`) у Python

> **Формат:** конспект у стилі Jupyter Notebook — чергуються Markdown‑пояснення та код‑осередки для запуску.

---

## 🎯 Мета та результати навчання

Після проходження цього модуля ви зможете:

* пояснити, як працює `print()` та налаштовувати вивід за допомогою параметрів `sep` і `end`;
* використовувати `input()` для отримання даних від користувача та коректно перетворювати типи (`int`, `float`, `str`);
* форматувати рядки за допомогою **f-strings** (точність, ширина, вирівнювання, роздільники тисяч);
* працювати з багаторядковими рядками та спеціальними символами (`\n`, `\t`, `\\`, лапки);
* написати прості інтерактивні міні‑програми (привітання, конвертери, калькулятори).

> **Передумови:** базовий синтаксис Python (змінні, типи даних), вміння запускати клітинки в Jupyter/Colab.

---

## 🧭 Зміст

* [Як працювати з блокнотом](#як-працювати-з-блокнотом)
* [1. `print()` — виведення даних](#1-print--виведення-даних)
* [2. `input()` — отримання даних](#2-input--отримання-даних)
* [3. Перетворення типів](#3-перетворення-типів)
* [4. Практика: простий калькулятор](#4-практика-простий-калькулятор)
* [5. Форматовані рядки (f‑strings)](#5-форматовані-рядки-fstrings)
* [6. Багаторядкові рядки](#6-багаторядкові-рядки)
* [7. Спеціальні символи та raw‑рядки](#7-спеціальні-символи-та-rawрядки)
* [8. Міні‑проєкти](#8-мініпроєкти)
* [Підсумок + Шпаргалка](#підсумок--шпаргалка)
* [Контрольні питання](#контрольні-питання)
* [Домашня практика](#домашня-практика)

---

## Як працювати з блокнотом

1. Запускайте клітинки коду по черзі зверху вниз.
2. Якщо щось «зависло», виконайте **Kernel → Restart** і запускайте знову.
3. Якщо середовище не підтримує інтерактивний ввід, ви можете:

   * замінити `input()` на заздалегідь визначені значення,
   * або використати конструкцію `try/except EOFError` (приклади нижче).

---

## 1. `print()` — виведення даних

### 📘 Теорія

`print()` виводить передані значення у стандартний потік виводу. Ключові параметри:

* `sep` — роздільник між елементами (за замовчуванням пробіл `' '`)
* `end` — «хвіст» наприкінці рядка (за замовчуванням новий рядок `"\n"`)

### ▶️ Код‑клітинка

```python
print("=" * 50)
print("1. ОСНОВИ print()")
print("=" * 50)

# Простий текст
print("Привіт, світ!")
print("Hello, World!")

# Виведення чисел
print(42)
print(3.14)

# Виведення декількох значень
print("Моє ім'я:", "Іван", "Мені", 25, "років")

# Параметр sep (separator) — роздільник між елементами
print("Python", "Java", "JavaScript", sep=" | ")
print("2024", "10", "23", sep="-")  # 2024-10-23

# Параметр end — що виводити в кінці (типово "\n")
print("Перший рядок", end=" ")
print("Той самий рядок!")  # Виведеться в один рядок

# Повернення до звичайної поведінки
print("А це вже новий рядок")

# Комбінація sep та end
print("Рахунок:", 1, 2, 3, sep="-", end=" | ")
print("Продовження")

print()  # Пустий рядок для відступу
```

### ✅ Поради

* Для логів зручно використовувати явні роздільники: `sep=","` або `sep=" | "`.
* Уникайте конкатенації чисел і рядків через `+` — використовуйте коми або f‑strings.

### 🧪 Самоперевірка

Спробуйте за один виклик `print()` вивести дату в форматі `YYYY/MM/DD`, використавши `sep`.

---

## 2. `input()` — отримання даних

### 📘 Теорія

* `input(prompt)` показує підказку та **завжди повертає рядок** (`str`).
* Часто потрібно перетворювати рядок на число: `int(...)`, `float(...)`.

### ▶️ Базове використання

```python
# Розкоментуйте для інтерактивної перевірки
# name = input("Введіть ваше ім'я: ")
# print("Привіт,", name)

# age_str = input("Скільки вам років? ")
# print("Ви ввели:", age_str)
# print("Тип даних:", type(age_str))  # <class 'str'>
```

### ⚠️ Типові помилки

* `ValueError` при `int("19.5")` або `int("abc")`. Використовуйте `float()` або перевірку введення.
* Порожній ввід. Додавайте валідацію (цикл `while`, перевірки `str.isdigit()` тощо).

---

## 3. Перетворення типів

### 📘 Теорія

* `int("25") → 25`
* `float("19.99") → 19.99`
* `str(42) → "42"`

### ▶️ Демонстрація

```python
print("=" * 50)
print("3. ПЕРЕТВОРЕННЯ ТИПІВ")
print("=" * 50)

# Перетворення рядка в число
age_str = "25"
age_int = int(age_str)
print(f"Рядок: {age_str}, тип: {type(age_str)}")
print(f"Число: {age_int}, тип: {type(age_int)}")

# Перетворення рядка у число з плаваючою точкою
price_str = "19.99"
price_float = float(price_str)
print(f"Рядок: {price_str}, тип: {type(price_str)}")
print(f"Float: {price_float}, тип: {type(price_float)}")

# Перетворення числа в рядок
number = 42
text = str(number)
print(f"Число: {number}, тип: {type(number)}")
print(f"Рядок: {text}, тип: {type(text)}")
```

### 🧩 Задача‑міні

Напишіть функцію `safe_int(prompt)`, яка запитує число до тих пір, поки користувач не введе коректне ціле.

<details>
<summary>Можливе рішення</summary>

```python
def safe_int(prompt="Введіть ціле число: "):
    while True:
        s = input(prompt)
        if s.strip().lstrip("-+").isdigit():
            return int(s)
        print("Спробуйте ще раз — це має бути ціле число.")
```

</details>

---

## 4. Практика: простий калькулятор

### 📘 Ідея

Попросити у користувача два числа, скласти та красиво вивести результат.

### ▶️ Варіант із демо‑значеннями (зручно, якщо `input()` недоступний)

```python
print("=" * 50)
print("4. ПРАКТИКА: ПРОСТИЙ КАЛЬКУЛЯТОР")
print("=" * 50)

def simple_calculator():
    """Приклад роботи з input та перетворенням типів"""

    print("\n🧮 Калькулятор для додавання двох чисел\n")

    # Якщо потрібна повна інтерактивність — розкоментуйте:
    # num1 = float(input("Введіть перше число: "))
    # num2 = float(input("Введіть друге число: "))

    # Демо-значення (працює там, де input заборонений)
    num1 = 10.5
    num2 = 5.3

    result = num1 + num2
    print(f"\n{num1} + {num2} = {result}")
    print(f"Результат (2 знаки після коми): {result:.2f}")

# Розкоментуйте для запуску в інтерактивному середовищі:
# simple_calculator()
```

### 🔧 Варіант з обробкою помилок вводу

```python
def calculator_with_validation():
    def ask_float(msg):
        while True:
            try:
                return float(input(msg))
            except ValueError:
                print("Введіть число (можна з крапкою).")

    a = ask_float("Перше число: ")
    b = ask_float("Друге число: ")
    print(f"Сума: {a + b:.2f}")
```

---

## 5. Форматовані рядки (f‑strings)

### 📘 Теорія

* Інтерполяція: `f"Мене звати {name}, мені {age} років"`
* Форматування чисел: `:.2f` (точність), `:10.2f` (ширина + точність), `:,` (роздільник тисяч), `:.2%` (відсотки)

### ▶️ Приклади

```python
print("=" * 50)
print("5. F-STRINGS (форматовані рядки)")
print("=" * 50)

name = "Олексій"
age = 28
height = 1.82

# Старі підходи
print("Мене звати " + name + ", мені " + str(age) + " років")
print("Мене звати {}, мені {} років".format(name, age))

# Сучасний спосіб — f-strings
print(f"Мене звати {name}, мені {age} років")
print(f"Через 5 років мені буде {age + 5} років")
print(f"Мій зріст: {height} м або {height * 100} см")

price = 1234.5
print(f"Ціна: {price:.2f} грн")       # 2 знаки після коми
print(f"Ціна: {price:10.2f} грн")     # ширина 10 символів
print(f"Ціна: {price:,.2f} грн")      # роздільник тисяч

pi = 3.14159265359
print(f"Число пі: {pi:.2f}")
print(f"Число пі: {pi:.4f}")

ratio = 0.0785
print(f"Частка: {ratio:.2%}")  # 7.85%

# Вирівнювання
print(f"|{123:>6}| праворуч")
print(f"|{123:<6}| ліворуч")
print(f"|{123:^6}| по центру")
```

### 💡 Порада

Для складних форматів дивіться «Format Specification Mini‑Language» (Python docs).

---

## 6. Багаторядкові рядки

### 📘 Теорія

Використовуйте потрійні лапки `"""..."""` або `'''...'''` для багаторядкових повідомлень/шаблонів. Їх зручно комбінувати з f‑strings.

### ▶️ Приклади

```python
print("=" * 50)
print("6. БАГАТОРЯДКОВІ РЯДКИ")
print("=" * 50)

message = """
Це багаторядковий текст.
Він може містити декілька рядків.
Зручно для довгих повідомлень!
"""
print(message)

name = "Марія"
greeting = f"""
Привіт, {name}!

Це багаторядкове привітання.
Сподіваємось, у тебе чудовий день!
"""
print(greeting)
```

> **Note:** Якщо ви вставляєте багаторядковий текст всередину коду з відступами, зайві пробіли можна прибрати через `textwrap.dedent`.

---

# %% [markdown]
# ## 7. Спеціальні символи та raw‑рядки

# %% [markdown]
# ### 📘 Теорія
#
# * `\n` — новий рядок
# * `\t` — табуляція
# * `\\` — зворотний слеш
# * `\'` та `\"` — лапки всередині рядка
# * **raw‑рядки**: `r"C:\\Users\\Docs"` — не обробляють escape‑послідовності

# %%
### ▶️ Приклади

# %%
```python
print("=" * 50)
print("7. СПЕЦІАЛЬНІ СИМВОЛИ")
print("=" * 50)

print("Перший рядок\nДругий рядок\nТретій рядок")
print("Колонка1\tКолонка2\tКолонка3")
print("Значення1\tЗначення2\tЗначення3")

print("Шлях: C:\\Users\\Documents\\file.txt")
print("Він сказав: \"Привіт!\"")
print('It\'s a beautiful day!')

# Raw string — зручно для шляхів на Windows та regex
path = r"C:\Users\Documents\file.txt"
print("Raw path:", path)

# Корисно іноді подивитись "як Python бачить рядок" (з екранами)
print("repr приклад:", repr("\tТекст\nКінець"))
```

---

# %%
## 8. Міні‑проєкти

# %%
### 8.1 Привітання користувача

# %%
```python
def greet_user():
    """Привітати користувача за ім'ям"""
    # name = input("Як вас звати? ")
    # print(f"Приємно познайомитись, {name}!")

    # Для демо без input:
    name = "Андрій"
    print(f"Приємно познайомитись, {name}!")

print("\n--- Приклад 1: Привітання ---")
greet_user()
```

### 8.2 Вік у днях

```python
def calculate_age_in_days():
    """Розрахувати вік у днях (≈ без урахування високосних років)"""
    # age = int(input("Скільки вам років? "))

    # Для демо:
    age = 25

    days = age * 365
    print(f"Вам приблизно {days} днів!")

print("\n--- Приклад 2: Вік у днях ---")
calculate_age_in_days()
```

# %%
### 8.3 Конвертер температури (°C → °F)

# %%
```python
def temperature_converter():
    """Конвертер температури Цельсій → Фаренгейт"""
    # celsius = float(input("Температура в Цельсіях: "))

    # Для демо:
    celsius = 25

    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius}°C = {fahrenheit}°F")

print("\n--- Приклад 3: Конвертер температури ---")
temperature_converter()
```

---

# %%
## Підсумок + Шпаргалка

# %%
```python
print("\n" + "=" * 50)
print("ПІДСУМОК")
print("=" * 50)

summary = """
✅ print() — виводить дані на екран
   - sep: роздільник між елементами
   - end: що виводити в кінці

✅ input() — отримує дані від користувача
   - завжди повертає рядок (string)

✅ Перетворення типів:
   - int() — в ціле число
   - float() — в дробове число
   - str() — в рядок

✅ f-strings — сучасний спосіб форматування:
   f"Текст {змінна} текст"
   - точність: {x:.2f}
   - ширина:  {x:10.2f}
   - тисячі:  {x:,.2f}
   - відсотки:{p:.2%}

✅ Спеціальні символи:
   \\n — зворотний слеш
   \\n — новий рядок
   \\t — табуляція
"""
print(summary)
```

---

# %%
## Контрольні питання

1. Чим відрізняються параметри `sep` і `end` у `print()`?
2. Чому `input()` завжди повертає рядок і коли треба робити перетворення типів?
3. Як вивести число з двома знаками після коми та з роздільником тисяч?
4. Яка різниця між звичайним і raw‑рядком? Наведіть приклад.
5. Як коректно обробити помилкове введення користувача?

# %%
---

## Домашня практика

> Розкоментуйте блоки коду, якщо працюєте в інтерактивному середовищі (Jupyter/Colab).

# %%
### Завдання 1: Персональна інформація

# %%
```python
# name = input("Ваше ім'я: ")
# age = int(input("Ваш вік: "))
# city = input("Ваше місто: ")
#
# print(f"\nВаші дані:")
# print(f"Ім'я: {name}")
# print(f"Вік: {age} років")
# print(f"Місто: {city}")
```

# %%
### Завдання 2: Калькулятор площі прямокутника

# %%
```python
# width = float(input("Ширина прямокутника: "))
# height = float(input("Висота прямокутника: "))
#
# area = width * height
# perimeter = 2 * (width + height)
#
# print(f"\nРезультати:")
# print(f"Площа: {area:.2f}")
# print(f"Периметр: {perimeter:.2f}")
```

# %%
### Додатково ⭐

* Реалізуйте міні‑калькулятор (+, −, ×, ÷) з меню та обробкою ділення на нуль.
* Напишіть конвертер валюти з красивим форматуванням `:,.2f`.
* Створіть генератор чеків: вводите позиції та ціни, виводите вирівняну таблицю.

---

# %%
## Завершення

# %%
```python
print("\n✨ Модуль завершено! Практикуйтесь з input та print! ✨\n")
```

# %% [markdown]
# # 03 modern

# %% [markdown]
# # 04

# %% [markdown]
# # 04 modern

# %% [markdown]
# # 05

# %% [markdown]
# # 05 modern

# %% [markdown]
# # 06

# %% [markdown]
# # 06 modern

# %% [markdown]
# # 07

# %% [markdown]
# # 07 modern
